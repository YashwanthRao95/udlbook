# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/yp/v6ljndhd4kj7jl5xwmj97hyc0000gn/T/pip-req-build-nawhabf4
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/yp/v6ljndhd4kj7jl5xwmj97hyc0000gn/T/pip-req-build-nawhabf4
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from mnist1d==0.0.2.post16) (2.31.0)
# Requirement already satisfied: numpy in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from mnist1d==0.0.2.post16) (1.24.3)
# Requirement already satisfied: matplotlib in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from mnist1d==0.0.2.post16) (3.7.2)
# Requirement already satisfied: scipy in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from mnist1d==0.0.2.post16) (1.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post16) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post16) (10.2.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from requests->mnist1d==0.0.2.post16) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from requests->mnist1d==0.0.2.post16) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from requests->mnist1d==0.0.2.post16) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from requests->mnist1d==0.0.2.post16) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14626 sha256=19d44813c3e49985207b590de7deacf749b92744e98b7720228c685a1647bc2b
#   Stored in directory: /private/var/folders/yp/v6ljndhd4kj7jl5xwmj97hyc0000gn/T/pip-ephem-wheel-cache-26s12ig2/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 200   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
  torch.nn.Linear(D_i, D_k),
  torch.nn.ReLU(),
  torch.nn.Linear(D_k, D_k),
  torch.nn.ReLU(),
  torch.nn.Linear(D_k, D_o))


def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=200, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=200, out_features=200, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=200, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.1, momentum=0.6)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=64, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.415107, train error 53.50,  test loss 1.537379, test error 61.50
# Epoch     1, train loss 1.164112, train error 40.17,  test loss 1.417230, test error 55.50
# Epoch     2, train loss 1.024907, train error 37.22,  test loss 1.372805, test error 54.50
# Epoch     3, train loss 0.841978, train error 28.12,  test loss 1.252277, test error 48.50
# Epoch     4, train loss 0.782879, train error 26.97,  test loss 1.269611, test error 49.90
# Epoch     5, train loss 0.666283, train error 22.00,  test loss 1.217393, test error 46.70
# Epoch     6, train loss 0.524276, train error 16.00,  test loss 1.163941, test error 41.70
# Epoch     7, train loss 0.453439, train error 13.50,  test loss 1.158393, test error 42.60
# Epoch     8, train loss 0.356336, train error 9.75,  test loss 1.155378, test error 40.10
# Epoch     9, train loss 0.334994, train error 9.47,  test loss 1.200735, test error 40.30
# Epoch    10, train loss 0.218534, train error 3.07,  test loss 1.110719, test error 38.40
# Epoch    11, train loss 0.189899, train error 2.45,  test loss 1.101213, test error 38.80
# Epoch    12, train loss 0.166754, train error 1.55,  test loss 1.099139, test error 36.50
# Epoch    13, train loss 0.149379, train error 1.28,  test loss 1.160749, test error 39.00
# Epoch    14, train loss 0.138261, train error 1.25,  test loss 1.181152, test error 38.80
# Epoch    15, train loss 0.113352, train error 0.47,  test loss 1.155936, test error 38.30
# Epoch    16, train loss 0.100889, train error 0.30,  test loss 1.169312, test error 37.40
# Epoch    17, train loss 0.091585, train error 0.20,  test loss 1.178457, test error 37.80
# Epoch    18, train loss 0.079469, train error 0.15,  test loss 1.190334, test error 36.80
# Epoch    19, train loss 0.070447, train error 0.07,  test loss 1.208318, test error 37.50
# Epoch    20, train loss 0.063687, train error 0.03,  test loss 1.219200, test error 38.00
# Epoch    21, train loss 0.061807, train error 0.05,  test loss 1.226256, test error 37.40
# Epoch    22, train loss 0.058147, train error 0.00,  test loss 1.229315, test error 37.50
# Epoch    23, train loss 0.054855, train error 0.00,  test loss 1.230253, test error 37.50
# Epoch    24, train loss 0.053382, train error 0.03,  test loss 1.245789, test error 37.20
# Epoch    25, train loss 0.050941, train error 0.00,  test loss 1.245366, test error 37.40
# Epoch    26, train loss 0.048380, train error 0.00,  test loss 1.249828, test error 37.20
# Epoch    27, train loss 0.046325, train error 0.00,  test loss 1.255472, test error 37.40
# Epoch    28, train loss 0.045032, train error 0.00,  test loss 1.271150, test error 38.40
# Epoch    29, train loss 0.043425, train error 0.00,  test loss 1.267203, test error 38.10
# Epoch    30, train loss 0.041592, train error 0.00,  test loss 1.269351, test error 37.60
# Epoch    31, train loss 0.040853, train error 0.00,  test loss 1.271915, test error 37.40
# Epoch    32, train loss 0.039957, train error 0.00,  test loss 1.275849, test error 37.30
# Epoch    33, train loss 0.039263, train error 0.00,  test loss 1.280456, test error 37.50
# Epoch    34, train loss 0.038736, train error 0.00,  test loss 1.281606, test error 37.80
# Epoch    35, train loss 0.037986, train error 0.00,  test loss 1.287240, test error 37.30
# Epoch    36, train loss 0.037263, train error 0.00,  test loss 1.290576, test error 38.00
# Epoch    37, train loss 0.036670, train error 0.00,  test loss 1.291825, test error 37.90
# Epoch    38, train loss 0.036093, train error 0.00,  test loss 1.292111, test error 37.70
# Epoch    39, train loss 0.035601, train error 0.00,  test loss 1.294359, test error 37.30
# Epoch    40, train loss 0.035092, train error 0.00,  test loss 1.297544, test error 37.80
# Epoch    41, train loss 0.034792, train error 0.00,  test loss 1.299532, test error 38.00
# Epoch    42, train loss 0.034505, train error 0.00,  test loss 1.301915, test error 37.90
# Epoch    43, train loss 0.034232, train error 0.00,  test loss 1.302511, test error 37.80
# Epoch    44, train loss 0.033944, train error 0.00,  test loss 1.303415, test error 38.10
# Epoch    45, train loss 0.033692, train error 0.00,  test loss 1.305815, test error 37.50
# Epoch    46, train loss 0.033408, train error 0.00,  test loss 1.307042, test error 37.60
# Epoch    47, train loss 0.033151, train error 0.00,  test loss 1.308578, test error 37.80
# Epoch    48, train loss 0.032903, train error 0.00,  test loss 1.308780, test error 37.60
# Epoch    49, train loss 0.032648, train error 0.00,  test loss 1.310053, test error 37.60

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
