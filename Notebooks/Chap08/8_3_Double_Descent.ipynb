# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/yp/v6ljndhd4kj7jl5xwmj97hyc0000gn/T/pip-req-build-305x5jit
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/yp/v6ljndhd4kj7jl5xwmj97hyc0000gn/T/pip-req-build-305x5jit
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from mnist1d==0.0.2.post16) (2.31.0)
# Requirement already satisfied: numpy in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from mnist1d==0.0.2.post16) (1.24.3)
# Requirement already satisfied: matplotlib in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from mnist1d==0.0.2.post16) (3.7.2)
# Requirement already satisfied: scipy in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from mnist1d==0.0.2.post16) (1.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post16) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post16) (10.2.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from requests->mnist1d==0.0.2.post16) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from requests->mnist1d==0.0.2.post16) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from requests->mnist1d==0.0.2.post16) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from requests->mnist1d==0.0.2.post16) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /Users/yashwanthraogujja/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.295364, train error 89.55,  test loss 2.295693, test error 89.47
# Epoch   100, train loss 1.917777, train error 72.70,  test loss 1.765749, test error 70.60
# Epoch   200, train loss 1.918969, train error 71.40,  test loss 1.753606, test error 69.57
# Epoch   300, train loss 1.908324, train error 70.90,  test loss 1.745586, test error 68.82
# Epoch   400, train loss 1.909153, train error 72.35,  test loss 1.734845, test error 69.72
# Epoch   500, train loss 1.922079, train error 71.20,  test loss 1.763094, test error 70.28
# Epoch   600, train loss 1.903678, train error 71.10,  test loss 1.733523, test error 68.75
# Epoch   700, train loss 1.905262, train error 71.78,  test loss 1.732160, test error 70.40
# Epoch   800, train loss 1.915098, train error 73.30,  test loss 1.733559, test error 70.85
# Epoch   900, train loss 1.903906, train error 71.38,  test loss 1.731539, test error 69.28
# Training model with   4 hidden variables
# Epoch     0, train loss 2.303563, train error 89.43,  test loss 2.302661, test error 88.57
# Epoch   100, train loss 1.777428, train error 65.60,  test loss 1.620152, test error 63.22
# Epoch   200, train loss 1.760660, train error 64.85,  test loss 1.597323, test error 63.35
# Epoch   300, train loss 1.750999, train error 64.15,  test loss 1.591184, test error 61.85
# Epoch   400, train loss 1.724854, train error 62.60,  test loss 1.541118, test error 59.75
# Epoch   500, train loss 1.734033, train error 63.45,  test loss 1.541901, test error 61.70
# Epoch   600, train loss 1.720898, train error 61.83,  test loss 1.534331, test error 59.70
# Epoch   700, train loss 1.721293, train error 62.30,  test loss 1.540280, test error 59.45
# Epoch   800, train loss 1.718333, train error 62.38,  test loss 1.532529, test error 59.72
# Epoch   900, train loss 1.726362, train error 62.67,  test loss 1.543235, test error 59.30
# Training model with   6 hidden variables
# Epoch     0, train loss 2.296966, train error 88.10,  test loss 2.301242, test error 88.70
# Epoch   100, train loss 1.780701, train error 65.80,  test loss 1.698289, test error 66.62
# Epoch   200, train loss 1.701095, train error 61.25,  test loss 1.588670, test error 61.22
# Epoch   300, train loss 1.672813, train error 59.22,  test loss 1.567704, test error 59.72
# Epoch   400, train loss 1.663760, train error 59.38,  test loss 1.559518, test error 59.60
# Epoch   500, train loss 1.651841, train error 58.75,  test loss 1.556763, test error 59.20
# Epoch   600, train loss 1.648468, train error 58.62,  test loss 1.552250, test error 59.40
# Epoch   700, train loss 1.641998, train error 58.40,  test loss 1.550539, test error 59.05
# Epoch   800, train loss 1.645903, train error 58.30,  test loss 1.554901, test error 58.58
# Epoch   900, train loss 1.639778, train error 58.67,  test loss 1.554470, test error 58.58
# Training model with   8 hidden variables
# Epoch     0, train loss 2.286508, train error 87.05,  test loss 2.276154, test error 88.10
# Epoch   100, train loss 1.647713, train error 58.78,  test loss 1.460422, test error 56.12
# Epoch   200, train loss 1.605999, train error 57.00,  test loss 1.446736, test error 55.88
# Epoch   300, train loss 1.585594, train error 56.22,  test loss 1.450877, test error 56.42
# Epoch   400, train loss 1.565400, train error 55.65,  test loss 1.440721, test error 56.33
# Epoch   500, train loss 1.555783, train error 55.83,  test loss 1.443595, test error 56.08
# Epoch   600, train loss 1.544288, train error 55.72,  test loss 1.443995, test error 56.35
# Epoch   700, train loss 1.551431, train error 55.53,  test loss 1.469342, test error 56.47
# Epoch   800, train loss 1.536278, train error 54.45,  test loss 1.452130, test error 55.17
# Epoch   900, train loss 1.532974, train error 54.38,  test loss 1.448993, test error 55.28
# Training model with  10 hidden variables
# Epoch     0, train loss 2.178537, train error 80.68,  test loss 2.159518, test error 79.53
# Epoch   100, train loss 1.506521, train error 50.90,  test loss 1.335268, test error 49.20
# Epoch   200, train loss 1.447576, train error 48.88,  test loss 1.308711, test error 49.40
# Epoch   300, train loss 1.426710, train error 48.22,  test loss 1.291104, test error 47.60
# Epoch   400, train loss 1.416364, train error 47.50,  test loss 1.280727, test error 48.10
# Epoch   500, train loss 1.411583, train error 47.60,  test loss 1.297619, test error 47.78
# Epoch   600, train loss 1.394306, train error 46.78,  test loss 1.300724, test error 48.17
# Epoch   700, train loss 1.382108, train error 46.30,  test loss 1.306635, test error 48.78
# Epoch   800, train loss 1.382089, train error 46.15,  test loss 1.303097, test error 47.95
# Epoch   900, train loss 1.375153, train error 45.65,  test loss 1.300456, test error 47.83
# Training model with  14 hidden variables
# Epoch     0, train loss 2.192103, train error 81.72,  test loss 2.158081, test error 80.22
# Epoch   100, train loss 1.468354, train error 51.12,  test loss 1.414058, test error 54.45
# Epoch   200, train loss 1.407016, train error 48.38,  test loss 1.422002, test error 53.62
# Epoch   300, train loss 1.372573, train error 47.78,  test loss 1.422351, test error 53.50
# Epoch   400, train loss 1.348988, train error 47.58,  test loss 1.430874, test error 53.28
# Epoch   500, train loss 1.340089, train error 47.28,  test loss 1.444689, test error 53.30
# Epoch   600, train loss 1.320558, train error 46.47,  test loss 1.448364, test error 53.40
# Epoch   700, train loss 1.308989, train error 45.60,  test loss 1.452049, test error 53.60
# Epoch   800, train loss 1.302475, train error 45.67,  test loss 1.459518, test error 53.25
# Epoch   900, train loss 1.303438, train error 46.35,  test loss 1.485510, test error 54.38
# Training model with  18 hidden variables
# Epoch     0, train loss 2.233089, train error 83.90,  test loss 2.220620, test error 83.85
# Epoch   100, train loss 1.340322, train error 45.38,  test loss 1.317517, test error 49.28
# Epoch   200, train loss 1.261020, train error 42.15,  test loss 1.336675, test error 48.67
# Epoch   300, train loss 1.222824, train error 41.38,  test loss 1.376580, test error 49.95
# Epoch   400, train loss 1.192891, train error 40.03,  test loss 1.425285, test error 50.70
# Epoch   500, train loss 1.180230, train error 39.28,  test loss 1.439094, test error 49.88
# Epoch   600, train loss 1.174701, train error 38.38,  test loss 1.451575, test error 50.28
# Epoch   700, train loss 1.152279, train error 38.20,  test loss 1.473453, test error 49.85
# Epoch   800, train loss 1.149814, train error 38.22,  test loss 1.514686, test error 50.00
# Epoch   900, train loss 1.141616, train error 37.83,  test loss 1.524031, test error 50.53
# Training model with  22 hidden variables
# Epoch     0, train loss 2.186616, train error 79.78,  test loss 2.150973, test error 79.75
# Epoch   100, train loss 1.290784, train error 42.67,  test loss 1.332532, test error 49.75
# Epoch   200, train loss 1.171422, train error 38.67,  test loss 1.358821, test error 49.28
# Epoch   300, train loss 1.095464, train error 36.28,  test loss 1.402073, test error 49.22
# Epoch   400, train loss 1.057516, train error 35.60,  test loss 1.475878, test error 50.42
# Epoch   500, train loss 1.033436, train error 34.95,  test loss 1.536916, test error 51.05
# Epoch   600, train loss 1.023235, train error 34.75,  test loss 1.590472, test error 51.70
# Epoch   700, train loss 1.013019, train error 34.10,  test loss 1.599261, test error 51.40
# Epoch   800, train loss 1.005227, train error 34.18,  test loss 1.659972, test error 52.42
# Epoch   900, train loss 0.984309, train error 32.95,  test loss 1.691500, test error 53.22
# Training model with  26 hidden variables
# Epoch     0, train loss 2.224173, train error 81.45,  test loss 2.222248, test error 81.82
# Epoch   100, train loss 1.211267, train error 39.83,  test loss 1.377415, test error 50.97
# Epoch   200, train loss 1.064691, train error 34.95,  test loss 1.473284, test error 51.92
# Epoch   300, train loss 0.984033, train error 32.80,  test loss 1.588678, test error 52.05
# Epoch   400, train loss 0.951712, train error 32.22,  test loss 1.695878, test error 53.25
# Epoch   500, train loss 0.922641, train error 31.57,  test loss 1.795467, test error 53.60
# Epoch   600, train loss 0.901332, train error 30.43,  test loss 1.870608, test error 55.40
# Epoch   700, train loss 0.880040, train error 30.15,  test loss 1.983376, test error 55.50
# Epoch   800, train loss 0.880568, train error 29.90,  test loss 2.059934, test error 55.75
# Epoch   900, train loss 0.860265, train error 29.28,  test loss 2.143217, test error 56.65
# Training model with  30 hidden variables
# Epoch     0, train loss 2.166392, train error 78.40,  test loss 2.134349, test error 77.75
# Epoch   100, train loss 1.108707, train error 36.03,  test loss 1.308479, test error 47.58
# Epoch   200, train loss 0.924091, train error 30.28,  test loss 1.497658, test error 50.12
# Epoch   300, train loss 0.831213, train error 27.38,  test loss 1.681505, test error 50.85
# Epoch   400, train loss 0.779846, train error 26.72,  test loss 1.897809, test error 52.75
# Epoch   500, train loss 0.736466, train error 24.70,  test loss 2.013622, test error 52.80
# Epoch   600, train loss 0.728249, train error 24.32,  test loss 2.161904, test error 53.75
# Epoch   700, train loss 0.705347, train error 23.45,  test loss 2.193490, test error 53.05
# Epoch   800, train loss 0.709786, train error 24.60,  test loss 2.313245, test error 52.80
# Epoch   900, train loss 0.672252, train error 22.70,  test loss 2.393236, test error 53.47
# Training model with  35 hidden variables
# Epoch     0, train loss 2.125810, train error 80.72,  test loss 2.078207, test error 80.65
# Epoch   100, train loss 1.014299, train error 32.78,  test loss 1.334371, test error 47.38
# Epoch   200, train loss 0.759966, train error 25.07,  test loss 1.694725, test error 50.72
# Epoch   300, train loss 0.664104, train error 22.38,  test loss 2.106802, test error 51.75
# Epoch   400, train loss 0.596588, train error 21.05,  test loss 2.480976, test error 53.78
# Epoch   500, train loss 0.542563, train error 18.22,  test loss 2.746445, test error 53.85
# Epoch   600, train loss 0.493138, train error 17.75,  test loss 3.144677, test error 54.20
# Epoch   700, train loss 0.466088, train error 16.57,  test loss 3.476463, test error 54.75
# Epoch   800, train loss 0.443913, train error 15.30,  test loss 3.777120, test error 55.20
# Epoch   900, train loss 0.419440, train error 15.40,  test loss 4.087505, test error 54.95
# Training model with  40 hidden variables
# Epoch     0, train loss 2.098974, train error 77.62,  test loss 2.040837, test error 76.85
# Epoch   100, train loss 0.909184, train error 29.30,  test loss 1.495263, test error 51.12
# Epoch   200, train loss 0.661552, train error 21.00,  test loss 1.985255, test error 53.72
# Epoch   300, train loss 0.531459, train error 17.28,  test loss 2.568251, test error 54.95
# Epoch   400, train loss 0.439042, train error 14.07,  test loss 3.189253, test error 56.35
# Epoch   500, train loss 0.381276, train error 13.32,  test loss 3.881948, test error 56.35
# Epoch   600, train loss 0.294314, train error 9.85,  test loss 4.600186, test error 58.35
# Epoch   700, train loss 0.317847, train error 11.40,  test loss 5.466581, test error 58.75
# Epoch   800, train loss 0.289353, train error 10.28,  test loss 6.168385, test error 58.42
# Epoch   900, train loss 0.252568, train error 9.00,  test loss 6.782418, test error 58.90
# Training model with  45 hidden variables
# Epoch     0, train loss 2.067616, train error 77.82,  test loss 2.025657, test error 77.22
# Epoch   100, train loss 0.850691, train error 27.22,  test loss 1.491196, test error 50.55
# Epoch   200, train loss 0.505068, train error 15.12,  test loss 2.149117, test error 52.78
# Epoch   300, train loss 0.358612, train error 11.12,  test loss 3.077582, test error 55.05
# Epoch   400, train loss 0.295851, train error 9.75,  test loss 4.128614, test error 55.83
# Epoch   500, train loss 0.188002, train error 5.57,  test loss 5.237934, test error 56.95
# Epoch   600, train loss 0.236596, train error 8.47,  test loss 6.167833, test error 55.25
# Epoch   700, train loss 0.308058, train error 10.03,  test loss 7.030346, test error 56.45
# Epoch   800, train loss 0.209466, train error 7.60,  test loss 7.939309, test error 55.65
# Epoch   900, train loss 0.190838, train error 6.12,  test loss 8.854255, test error 55.90
# Training model with  50 hidden variables
# Epoch     0, train loss 2.076780, train error 77.43,  test loss 2.024501, test error 75.82
# Epoch   100, train loss 0.701274, train error 21.62,  test loss 1.574035, test error 50.12
# Epoch   200, train loss 0.337517, train error 10.10,  test loss 2.677882, test error 54.08
# Epoch   300, train loss 0.103913, train error 1.15,  test loss 4.329473, test error 55.90
# Epoch   400, train loss 0.026827, train error 0.00,  test loss 5.817644, test error 55.92
# Epoch   500, train loss 0.012857, train error 0.00,  test loss 6.691182, test error 56.03
# Epoch   600, train loss 0.008282, train error 0.00,  test loss 7.304386, test error 56.05
# Epoch   700, train loss 0.006022, train error 0.00,  test loss 7.763218, test error 56.25
# Epoch   800, train loss 0.004668, train error 0.00,  test loss 8.120833, test error 56.28
# Epoch   900, train loss 0.003758, train error 0.00,  test loss 8.422549, test error 56.28
# Training model with  55 hidden variables
# Epoch     0, train loss 2.110806, train error 78.03,  test loss 2.059708, test error 77.50
# Epoch   100, train loss 0.643371, train error 19.75,  test loss 1.620867, test error 50.47
# Epoch   200, train loss 0.223365, train error 5.20,  test loss 3.065084, test error 55.03
# Epoch   300, train loss 0.038132, train error 0.03,  test loss 4.753669, test error 54.50
# Epoch   400, train loss 0.014610, train error 0.00,  test loss 5.792808, test error 54.67
# Epoch   500, train loss 0.008426, train error 0.00,  test loss 6.438552, test error 54.62
# Epoch   600, train loss 0.005720, train error 0.00,  test loss 6.882554, test error 54.70
# Epoch   700, train loss 0.004285, train error 0.00,  test loss 7.227747, test error 54.55
# Epoch   800, train loss 0.003380, train error 0.00,  test loss 7.520027, test error 54.65
# Epoch   900, train loss 0.002777, train error 0.00,  test loss 7.766354, test error 54.47
# Training model with  60 hidden variables
# Epoch     0, train loss 2.072747, train error 77.40,  test loss 2.020049, test error 76.38
# Epoch   100, train loss 0.540773, train error 16.12,  test loss 1.701571, test error 50.35
# Epoch   200, train loss 0.096634, train error 0.70,  test loss 3.292841, test error 52.28
# Epoch   300, train loss 0.018628, train error 0.00,  test loss 4.608642, test error 53.40
# Epoch   400, train loss 0.009004, train error 0.00,  test loss 5.276454, test error 53.65
# Epoch   500, train loss 0.005730, train error 0.00,  test loss 5.711895, test error 53.72
# Epoch   600, train loss 0.004093, train error 0.00,  test loss 6.038830, test error 54.00
# Epoch   700, train loss 0.003145, train error 0.00,  test loss 6.295212, test error 54.00
# Epoch   800, train loss 0.002530, train error 0.00,  test loss 6.510921, test error 54.00
# Epoch   900, train loss 0.002101, train error 0.00,  test loss 6.691345, test error 54.03
# Training model with  70 hidden variables
# Epoch     0, train loss 2.036770, train error 76.05,  test loss 1.982757, test error 76.43
# Epoch   100, train loss 0.374912, train error 10.07,  test loss 1.991948, test error 54.47
# Epoch   200, train loss 0.035280, train error 0.00,  test loss 3.576747, test error 55.17
# Epoch   300, train loss 0.011608, train error 0.00,  test loss 4.366542, test error 54.67
# Epoch   400, train loss 0.006496, train error 0.00,  test loss 4.826288, test error 55.00
# Epoch   500, train loss 0.004321, train error 0.00,  test loss 5.137395, test error 54.95
# Epoch   600, train loss 0.003198, train error 0.00,  test loss 5.379712, test error 55.08
# Epoch   700, train loss 0.002510, train error 0.00,  test loss 5.575914, test error 55.10
# Epoch   800, train loss 0.002047, train error 0.00,  test loss 5.732685, test error 55.00
# Epoch   900, train loss 0.001718, train error 0.00,  test loss 5.871018, test error 55.08
# Training model with  80 hidden variables
# Epoch     0, train loss 2.027002, train error 75.03,  test loss 1.989198, test error 76.15
# Epoch   100, train loss 0.218333, train error 3.78,  test loss 2.088700, test error 51.42
# Epoch   200, train loss 0.019327, train error 0.00,  test loss 3.402278, test error 51.85
# Epoch   300, train loss 0.007864, train error 0.00,  test loss 3.954823, test error 52.05
# Epoch   400, train loss 0.004674, train error 0.00,  test loss 4.280493, test error 52.08
# Epoch   500, train loss 0.003232, train error 0.00,  test loss 4.513041, test error 52.03
# Epoch   600, train loss 0.002437, train error 0.00,  test loss 4.689872, test error 52.10
# Epoch   700, train loss 0.001939, train error 0.00,  test loss 4.834387, test error 52.17
# Epoch   800, train loss 0.001600, train error 0.00,  test loss 4.956165, test error 52.15
# Epoch   900, train loss 0.001356, train error 0.00,  test loss 5.062986, test error 52.17
# Training model with  90 hidden variables
# Epoch     0, train loss 2.005442, train error 75.38,  test loss 1.926390, test error 74.43
# Epoch   100, train loss 0.150702, train error 1.88,  test loss 2.124426, test error 50.50
# Epoch   200, train loss 0.014547, train error 0.00,  test loss 3.109600, test error 50.75
# Epoch   300, train loss 0.006415, train error 0.00,  test loss 3.525960, test error 50.47
# Epoch   400, train loss 0.003938, train error 0.00,  test loss 3.778785, test error 50.70
# Epoch   500, train loss 0.002772, train error 0.00,  test loss 3.965417, test error 50.75
# Epoch   600, train loss 0.002108, train error 0.00,  test loss 4.110423, test error 50.90
# Epoch   700, train loss 0.001686, train error 0.00,  test loss 4.228952, test error 50.97
# Epoch   800, train loss 0.001398, train error 0.00,  test loss 4.329072, test error 50.92
# Epoch   900, train loss 0.001187, train error 0.00,  test loss 4.416238, test error 51.08
# Training model with 100 hidden variables
# Epoch     0, train loss 1.995683, train error 73.57,  test loss 1.919477, test error 72.95
# Epoch   100, train loss 0.089935, train error 0.18,  test loss 2.172665, test error 49.55
# Epoch   200, train loss 0.012431, train error 0.00,  test loss 3.018595, test error 49.92
# Epoch   300, train loss 0.005796, train error 0.00,  test loss 3.371127, test error 49.95
# Epoch   400, train loss 0.003594, train error 0.00,  test loss 3.597742, test error 49.75
# Epoch   500, train loss 0.002553, train error 0.00,  test loss 3.763445, test error 49.85
# Epoch   600, train loss 0.001955, train error 0.00,  test loss 3.890985, test error 49.95
# Epoch   700, train loss 0.001568, train error 0.00,  test loss 3.997636, test error 50.00
# Epoch   800, train loss 0.001302, train error 0.00,  test loss 4.086896, test error 50.08
# Epoch   900, train loss 0.001108, train error 0.00,  test loss 4.165246, test error 50.15
# Training model with 120 hidden variables
# Epoch     0, train loss 1.985551, train error 73.03,  test loss 1.927037, test error 72.78
# Epoch   100, train loss 0.057199, train error 0.00,  test loss 2.131494, test error 49.42
# Epoch   200, train loss 0.010051, train error 0.00,  test loss 2.764761, test error 49.53
# Epoch   300, train loss 0.004897, train error 0.00,  test loss 3.047355, test error 49.50
# Epoch   400, train loss 0.003114, train error 0.00,  test loss 3.228822, test error 49.58
# Epoch   500, train loss 0.002235, train error 0.00,  test loss 3.360505, test error 49.58
# Epoch   600, train loss 0.001724, train error 0.00,  test loss 3.465431, test error 49.53
# Epoch   700, train loss 0.001393, train error 0.00,  test loss 3.554322, test error 49.58
# Epoch   800, train loss 0.001161, train error 0.00,  test loss 3.628171, test error 49.60
# Epoch   900, train loss 0.000991, train error 0.00,  test loss 3.693558, test error 49.60
# Training model with 140 hidden variables
# Epoch     0, train loss 1.957566, train error 72.53,  test loss 1.868961, test error 72.90
# Epoch   100, train loss 0.039310, train error 0.00,  test loss 2.203273, test error 50.38
# Epoch   200, train loss 0.008343, train error 0.00,  test loss 2.712589, test error 50.28
# Epoch   300, train loss 0.004250, train error 0.00,  test loss 2.956926, test error 50.55
# Epoch   400, train loss 0.002752, train error 0.00,  test loss 3.116387, test error 50.55
# Epoch   500, train loss 0.001998, train error 0.00,  test loss 3.235993, test error 50.38
# Epoch   600, train loss 0.001551, train error 0.00,  test loss 3.330453, test error 50.45
# Epoch   700, train loss 0.001257, train error 0.00,  test loss 3.408518, test error 50.55
# Epoch   800, train loss 0.001052, train error 0.00,  test loss 3.475108, test error 50.53
# Epoch   900, train loss 0.000900, train error 0.00,  test loss 3.532235, test error 50.62
# Training model with 160 hidden variables
# Epoch     0, train loss 1.950170, train error 72.30,  test loss 1.891205, test error 73.72
# Epoch   100, train loss 0.028667, train error 0.00,  test loss 2.172775, test error 50.35
# Epoch   200, train loss 0.007174, train error 0.00,  test loss 2.597572, test error 50.22
# Epoch   300, train loss 0.003772, train error 0.00,  test loss 2.808486, test error 50.10
# Epoch   400, train loss 0.002480, train error 0.00,  test loss 2.948152, test error 50.20
# Epoch   500, train loss 0.001815, train error 0.00,  test loss 3.052266, test error 50.30
# Epoch   600, train loss 0.001416, train error 0.00,  test loss 3.136039, test error 50.15
# Epoch   700, train loss 0.001154, train error 0.00,  test loss 3.205666, test error 50.30
# Epoch   800, train loss 0.000968, train error 0.00,  test loss 3.264707, test error 50.38
# Epoch   900, train loss 0.000831, train error 0.00,  test loss 3.315674, test error 50.38
# Training model with 180 hidden variables
# Epoch     0, train loss 1.933912, train error 69.90,  test loss 1.867926, test error 72.45
# Epoch   100, train loss 0.023495, train error 0.00,  test loss 2.074729, test error 48.85
# Epoch   200, train loss 0.006427, train error 0.00,  test loss 2.429891, test error 48.58
# Epoch   300, train loss 0.003443, train error 0.00,  test loss 2.607659, test error 48.55
# Epoch   400, train loss 0.002281, train error 0.00,  test loss 2.724791, test error 48.55
# Epoch   500, train loss 0.001680, train error 0.00,  test loss 2.814131, test error 48.62
# Epoch   600, train loss 0.001317, train error 0.00,  test loss 2.885054, test error 48.67
# Epoch   700, train loss 0.001075, train error 0.00,  test loss 2.944608, test error 48.65
# Epoch   800, train loss 0.000905, train error 0.00,  test loss 2.995636, test error 48.67
# Epoch   900, train loss 0.000778, train error 0.00,  test loss 3.040396, test error 48.60
# Training model with 200 hidden variables
# Epoch     0, train loss 1.899995, train error 67.93,  test loss 1.809673, test error 70.57
# Epoch   100, train loss 0.021207, train error 0.00,  test loss 1.965034, test error 48.17
# Epoch   200, train loss 0.006129, train error 0.00,  test loss 2.272784, test error 47.70
# Epoch   300, train loss 0.003311, train error 0.00,  test loss 2.429672, test error 47.67
# Epoch   400, train loss 0.002211, train error 0.00,  test loss 2.538510, test error 47.53
# Epoch   500, train loss 0.001632, train error 0.00,  test loss 2.618654, test error 47.60
# Epoch   600, train loss 0.001282, train error 0.00,  test loss 2.683017, test error 47.45
# Epoch   700, train loss 0.001048, train error 0.00,  test loss 2.737807, test error 47.40
# Epoch   800, train loss 0.000883, train error 0.00,  test loss 2.784585, test error 47.53
# Epoch   900, train loss 0.000759, train error 0.00,  test loss 2.824912, test error 47.55
# Training model with 250 hidden variables
# Epoch     0, train loss 1.928903, train error 69.32,  test loss 1.834219, test error 69.30
# Epoch   100, train loss 0.016714, train error 0.00,  test loss 1.904781, test error 47.08
# Epoch   200, train loss 0.005285, train error 0.00,  test loss 2.159909, test error 47.20
# Epoch   300, train loss 0.002939, train error 0.00,  test loss 2.293373, test error 47.08
# Epoch   400, train loss 0.001983, train error 0.00,  test loss 2.383188, test error 47.17
# Epoch   500, train loss 0.001476, train error 0.00,  test loss 2.452796, test error 47.12
# Epoch   600, train loss 0.001165, train error 0.00,  test loss 2.508696, test error 47.05
# Epoch   700, train loss 0.000956, train error 0.00,  test loss 2.555527, test error 47.10
# Epoch   800, train loss 0.000807, train error 0.00,  test loss 2.596191, test error 47.10
# Epoch   900, train loss 0.000696, train error 0.00,  test loss 2.631476, test error 47.10
# Training model with 300 hidden variables
# Epoch     0, train loss 1.872939, train error 67.45,  test loss 1.813169, test error 69.65
# Epoch   100, train loss 0.014250, train error 0.00,  test loss 1.864718, test error 46.92
# Epoch   200, train loss 0.004764, train error 0.00,  test loss 2.087214, test error 46.83
# Epoch   300, train loss 0.002695, train error 0.00,  test loss 2.204642, test error 46.78
# Epoch   400, train loss 0.001835, train error 0.00,  test loss 2.286290, test error 46.60
# Epoch   500, train loss 0.001373, train error 0.00,  test loss 2.347948, test error 46.75
# Epoch   600, train loss 0.001088, train error 0.00,  test loss 2.398320, test error 46.60
# Epoch   700, train loss 0.000896, train error 0.00,  test loss 2.440545, test error 46.58
# Epoch   800, train loss 0.000758, train error 0.00,  test loss 2.477337, test error 46.53
# Epoch   900, train loss 0.000655, train error 0.00,  test loss 2.509223, test error 46.55
# Training model with 400 hidden variables
# Epoch     0, train loss 1.932011, train error 69.70,  test loss 1.897123, test error 72.10
# Epoch   100, train loss 0.011885, train error 0.00,  test loss 1.780199, test error 45.78
# Epoch   200, train loss 0.004214, train error 0.00,  test loss 1.958612, test error 45.40
# Epoch   300, train loss 0.002440, train error 0.00,  test loss 2.060987, test error 45.25
# Epoch   400, train loss 0.001681, train error 0.00,  test loss 2.131534, test error 45.33
# Epoch   500, train loss 0.001265, train error 0.00,  test loss 2.186130, test error 45.25
# Epoch   600, train loss 0.001007, train error 0.00,  test loss 2.229347, test error 45.15
# Epoch   700, train loss 0.000832, train error 0.00,  test loss 2.266381, test error 45.12
# Epoch   800, train loss 0.000706, train error 0.00,  test loss 2.298044, test error 45.10
# Epoch   900, train loss 0.000612, train error 0.00,  test loss 2.325885, test error 45.10

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
